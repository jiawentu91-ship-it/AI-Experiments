# %%
x,y,z,f=symbols('x,y,z,f')

# %%
x,y,z,f=symbols('x,y,z,f')
f=Function("f")
print(simplify(pow(x+2,2)-pow(x+1,2)))
print(simplify((x**2-1)/(x+1)))
print(simplify((f(x)**2-1)/(f(x)+1)))
print(simplify(sin(x)**2+2*sin(x)*cos(x)+cos(x)**2))
print(simplify(f(sin(x)**2+2*sin(x)*cos(x)+cos(x)**2)))
print(expand_trig(sin(2*x+y)))
print(factor(15*x**2+2*y-3*x-10*x*y))
# Out:
# 2*x + 3
# x - 1
# f(x) - 1
# sin(2*x) + 1
# f(sin(2*x) + 1)
# (2*cos(x)**2 - 1)*sin(y) + 2*sin(x)*cos(x)*cos(y)
# (3*x - 2*y)*(5*x - 1)

# %%
a,b,c = symbols("a,b,c") 
print(solve(a*x**2+b*x+c, x))
print(solve(x**2+3*x+1, x))
print(solve((x**2+x*y+1,y**2+x*y+2),x,y))
# Out:
# [(-b - sqrt(-4*a*c + b**2))/(2*a), (-b + sqrt(-4*a*c + b**2))/(2*a)]
# [-3/2 - sqrt(5)/2, -3/2 + sqrt(5)/2]
# [(-sqrt(3)*I/3, -2*sqrt(3)*I/3), (sqrt(3)*I/3, 2*sqrt(3)*I/3)]

# %%
f=Function('f')
a,b,c=symbols('a,b,c')
print(dsolve(a*Derivative(f(x),x,2)+b*Derivative(f(x),x)+c*f(x)+3,f(x)))
print(dsolve(1*Derivative(f(x),x,2)+(-3)*Derivative(f(x),x)+(-1)*f(x)+3,f(x)))
# Out:
# Eq(f(x), C1*exp(x*(-b + sqrt(-4*a*c + b**2))/(2*a)) + C2*exp(-x*(b + sqrt(-4*a*c + b**2))/(2*a)) - 3/c)
# Eq(f(x), C1*exp(x*(3 - sqrt(13))/2) + C2*exp(x*(3 + sqrt(13))/2) + 3)

# %%
a,b,c=symbols('a,b,c')
print(integrate(a*x**2+b*x+c,x))
print(integrate(a*x**2+b*x+c,(x,0,1)))
# Out:
# a*x**3/3 + b*x**2/2 + c*x
# a/3 + b/2 + c

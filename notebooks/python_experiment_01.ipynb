# %%
list1 = ['life', 'is', 'short']
list2 = ['You', 'need', 'python']
list1.append('!')
list1[0],list1.index('life'),list1
# Out:
# ('life', 0, ['life', 'is', 'short', '!'])

# %%
s=[9,7,8,3,2,1,5,6]
for i in range(8):
   if s[i]%2==0:
    s[i]=s[i]**2
s
# Out:
# [9, 7, 64, 3, 4, 1, 5, 36]

# %%
sex={'jwt':'男','try':'女','jf':'男','css':'女','wtt':'男','syy':'女'}
list=['jwt','try','jf','css','wtt','syy']
for i in range(5):
   if sex[list[i]]=='男':
        del sex[list[i]]
sex
# Out:
# {'try': '女', 'css': '女', 'syy': '女'}

# %%
A={1,2,3,4,5}
B={1,2,6,7,9}
A&B,A|B,A-B,B-A,A^B
# Out:
# ({1, 2}, {1, 2, 3, 4, 5, 6, 7, 9}, {3, 4, 5}, {6, 7, 9}, {3, 4, 5, 6, 7, 9})

# %%
import math
from abc import ABC,abstractmethod
class Shape(ABC):
    def __init__(self,name):
     self.name=name
    
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass
   
class Circle(Shape):
    def __init__(self,radius):
     super().__init__('圆形')
     self.radius=radius
    
    def area(self):
     return math.pi*(self.radius**2)
    
    def perimeter(self):
     return 2*math.pi*self.radius

class Rectangle(Shape):
    def __init__(self,width,height):
     super().__init__('矩形')
     self.width=width
     self.height=height
    
    def area(self):
        return self.width*self.height
    def perimeter(self):
        return 2*(self.width+self.height)

circle=Circle(2)
rectangle=Rectangle(2,4)
print(circle.name,circle.area(),circle.perimeter(),sep=',')
print(rectangle.name,rectangle.area(),rectangle.perimeter(),sep=',')
# Out:
# 圆形,12.566370614359172,12.566370614359172
# 矩形,8,12

# %%
width=int(input('请输入打印宽度：'))
width1=10
width2=width-width1
fmt1='{{0:{}}}{{1:>{}}}'.format(width2,width1)          
print('='*width)
print(fmt1.format('item',1.92))
print(fmt1)
# Out:
# 请输入打印宽度： 40
# ...
# item                                1.92
# {0:30}{1:>10}

# %%
import numpy as np
k=np.matrix('10,-2,-1;-1,12,-5;-1,-5,8')
f=np.matrix('10;20;15')
x=np.linalg.solve(k,f)
x
# Out:
# matrix([[2.18890555],
#         [3.71064468],
#         [4.46776612]])

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-5,5,100)
y=x**2
data=[12,42,30,60,87,99]
plt.subplot(1,2,1)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y,'-.')
plt.scatter(x,y)
plt.subplot(1,2,2)
plt.pie(data,explode=[0,0.5,0,0,0,0])
plt.show()

# %%
a=range(1,6)
# Out:
# range(1, 6)
